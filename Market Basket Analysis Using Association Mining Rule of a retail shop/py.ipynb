# %% [markdown]
# Market Basket Analysis using Associate Rule Mining

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# mlxtend~provides functions for reading and manipulating transactional data,generating association rules and evaluating quality.

# %%
retail=pd.read_csv('Online Retail.csv')
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#Data Cleaning
retail['Description']=retail['Description'].str.strip()#remove whitespace
retail.dropna(axis=0,subset=['InvoiceNo'],inplace=True)#remove dublicate invoices
retail["InvoiceNo"]=retail['InvoiceNo'].astype("str")#converting invoice number to be string
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
mybasket = (retail[retail['Country'] =="France"]#Separating transactions for Germany
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
mybasket.head() #0=not in paticular decription
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %%
#converting all positive vaues to 1 and everything else to 0
def my_encode_units(x):
    if x <=0:
        return 0
    if x>=1:
        return 1
mybasket_set=mybasket.applymap(my_encode_units)
mybasket_set.drop('POSTAGE',inplace=True,axis=1)#Remove"postage"as an item

# %% [markdown]
# Traning Model

# %%
  #Generate Frequent itemsets
frequent_itemsets=apriori(mybasket_set,min_support=0.07,use_colnames=True)
# Out:
# c:\Users\Sujit\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
#Generate rules
rules=association_rules(frequent_itemsets,metric="lift",min_threshold=1)

# %%
rules.head(100)
# Out:
#                                           antecedents  \
# 0                     (PLASTERS IN TIN CIRCUS PARADE)
# 1                          (PLASTERS IN TIN SPACEBOY)
# 2                     (PLASTERS IN TIN CIRCUS PARADE)
# 3                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 4                          (PLASTERS IN TIN SPACEBOY)
# 5                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 6                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 7                       (SET/6 RED SPOTTY PAPER CUPS)
# 8                     (SET/6 RED SPOTTY PAPER PLATES)
# 9                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 10                    (SET/6 RED SPOTTY PAPER PLATES)
# 11                      (SET/6 RED SPOTTY PAPER CUPS)
# 12  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 13  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 14  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 15                    (SET/6 RED SPOTTY PAPER PLATES)
# ...

# %% [markdown]
# My Recomandation

# %%
mybasket_set['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 62

# %%
mybasket_set['SPACEBOY LUNCH BOX'].sum()
# Out:
# 49

# %%
#Filtering rules based on condition
rules[(rules['lift']>=3)&
      (rules['confidence']>0.3)]
# Out:
#                                           antecedents  \
# 0                     (PLASTERS IN TIN CIRCUS PARADE)
# 1                          (PLASTERS IN TIN SPACEBOY)
# 2                     (PLASTERS IN TIN CIRCUS PARADE)
# 3                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 4                          (PLASTERS IN TIN SPACEBOY)
# 5                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 6                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 7                       (SET/6 RED SPOTTY PAPER CUPS)
# 8                     (SET/6 RED SPOTTY PAPER PLATES)
# 9                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 10                    (SET/6 RED SPOTTY PAPER PLATES)
# 11                      (SET/6 RED SPOTTY PAPER CUPS)
# 12  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 13  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 14  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 15                    (SET/6 RED SPOTTY PAPER PLATES)
# ...
